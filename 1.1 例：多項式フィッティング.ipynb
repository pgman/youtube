# %% [markdown]
# # 1.1 例：多項式フィッティング

# %% [markdown]
# 訓練集合として、$N$個の観測値$x$を並べた${\bf x}\equiv\begin{pmatrix}x_1,\cdots,x_N\end{pmatrix}$と<br>それに対応する観測値$t$を並べた${\bf t}\equiv\begin{pmatrix}t_1,\cdots,t_N\end{pmatrix}$が与えられているとする。<br>
# <br>
# 我々の目標は、この訓練集合を利用して、<br>
# 新たな入力変数の値$\hat{x}$に対して目標変数$\hat{t}$の値を予測することである。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 曲線フィッティングに基づく単純なアプローチを考える。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# aaaaaaaa

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# aaa
